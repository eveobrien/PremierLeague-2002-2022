# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px

#note to self - see how many years of historic data there is on football-data.co.uk & utilise it

# %%
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', None)

# %%
Season1718 = pd.read_csv("1718.csv")

# %%
Season1718.head()
# Out:
#   Div        Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR      Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A    BWH   BWD    BWA   IWH  IWD    IWA    LBH   LBD    LBA    PSH   PSD    PSA    WHH  WHD    WHA    VCH   VCD    VCA  Bb1X2  BbMxH  BbAvH  BbMxD  BbAvD  BbMxA  BbAvA  BbOU  BbMx>2.5  BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA   PSCH  PSCD   PSCA
# 0  E0  11/08/2017         Arsenal     Leicester     4     3   H     2     2   D       M Dean  27   6   10    3   9  12   9   4   0   1   0   0   1.53    4.5   6.50   1.50  4.60   6.75  1.47  4.5   6.50   1.44  4.40   6.50   1.53  4.55   6.85   1.53  4.2   6.00   1.53  4.50   6.50     41   1.55   1.51   4.60   4.43   6.89   6.44    37      1.65      1.61      2.43      2.32    21  -1.00     1.91     1.85     2.10     2.02   1.49  4.73   7.25
# ...

# %%
Season1819 = pd.read_csv("1819.csv")

# %%
Season1819.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A   BWH  BWD   BWA   IWH   IWD   IWA   PSH   PSD   PSA   WHH  WHD   WHA   VCH  VCD   VCA  Bb1X2  BbMxH  BbAvH  BbMxD  BbAvD  BbMxA  BbAvA  BbOU  BbMx>2.5  BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  PSCA
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0   H  A Marriner   8  13    6    4  11   8   2   5   2   1   0   0   1.57    3.9   7.50  1.53  4.0  7.50  1.55  3.80  7.00  1.58  3.93  7.50  1.57  3.8  6.00  1.57  4.0  7.00     39   1.60   1.56   4.20   3.92   8.05   7.06    38      2.12      2.03      1.85      1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55  4.07  7.69
# ...

# %%
Season1920 = pd.read_csv("1920.csv")

# %%
Season1920.head()
# Out:
#   Div        Date   Time        HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A    BWH   BWD    BWA    IWH   IWD    IWA    PSH   PSD    PSA    WHH  WHD    WHA    VCH  VCD    VCA   MaxH   MaxD   MaxA   AvgH  AvgD   AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA   BWCH  BWCD   BWCA   IWCH  IWCD   IWCA   PSCH   PSCD   PSCA   WHCH  WHCD   WHCA   VCCH  VCCD   VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
Season2021 = pd.read_csv("2021.csv")

# %%
Season2021.head()
# Out:
#   Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A   BWH   BWD    BWA   IWH   IWD   IWA   PSH   PSD   PSA   WHH  WHD    WHA   VCH   VCD    VCA  MaxH  MaxD   MaxA  AvgH  AvgD  AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD   BWCA  IWCH  IWCD  IWCA  PSCH  PSCD   PSCA  WHCH  WHCD   WHCA  VCCH  VCCD   VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
Season2122 = pd.read_csv("2122.csv")

# %%
Season2122.head()
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR    Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A   BWH   BWD    BWA   IWH   IWD    IWA   PSH   PSD    PSA   WHH   WHD    WHA   VCH   VCD    VCA  MaxH  MaxD   MaxA  AvgH  AvgD   AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD   BWCA  IWCH  IWCD   IWCA  PSCH  PSCD   PSCA  WHCH  WHCD   WHCA  VCCH  VCCD   VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
Season2223 = pd.read_csv("2223.csv")

# %%
Season22231 = pd.read_csv("22231.csv")

# %%
Season2223.head()
# Out:
#   Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A    BWH   BWD   BWA    IWH   IWD   IWA    PSH   PSD   PSA    WHH  WHD   WHA    VCH  VCD   VCA   MaxH  MaxD  MaxA   AvgH  AvgD  AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD  BWCA   IWCH  IWCD  IWCA   PSCH  PSCD  PSCA   WHCH  WHCD  WHCA   VCCH  VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %%
Season22231.head()
# Out:
#   Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A    BWH   BWD   BWA    IWH   IWD   IWA    PSH   PSD   PSA    WHH  WHD   WHA    VCH  VCD   VCA   MaxH  MaxD  MaxA   AvgH  AvgD  AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD  BWCA   IWCH  IWCD  IWCA   PSCH  PSCD  PSCA   WHCH  WHCD  WHCA   VCCH  VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# ...

# %% [markdown]
# # Column Definitions:
#
# Key to results data:
#
# - Div = League Division
#
# - Date = Match Date (dd/mm/yy)
#
# - Time = Time of match kick off
#
# - HomeTeam = Home Team
#
# - AwayTeam = Away Team
#
# - FTHG and HG = Full Time Home Team Goals
#
# - FTAG and AG = Full Time Away Team Goals
#
# - FTR and Res = Full Time Result (H=Home Win, D=Draw, A=Away Win)
#
# - HTHG = Half Time Home Team Goals
#
# - HTAG = Half Time Away Team Goals
#
# - HTR = Half Time Result (H=Home Win, D=Draw, A=Away Win)
#
#
# # Match Statistics (where available)
#
# - Attendance = Crowd Attendance
#
# - Referee = Match Referee
#
# - HS = Home Team Shots
#
# - AS = Away Team Shots
#
# - HST = Home Team Shots on Target
#
# - AST = Away Team Shots on Target
#
# - HHW = Home Team Hit Woodwork
#
# - AHW = Away Team Hit Woodwork
#
# - HC = Home Team Corners
#
# - AC = Away Team Corners
#
# - HF = Home Team Fouls Committed
#
# - AF = Away Team Fouls Committed
#
# - HFKC = Home Team Free Kicks Conceded
#
# - AFKC = Away Team Free Kicks Conceded
#
# - HO = Home Team Offsides
#
# - AO = Away Team Offsides
#
# - HY = Home Team Yellow Cards
#
# - AY = Away Team Yellow Cards
#
# - HR = Home Team Red Cards
#
# -  AR = Away Team Red Cards
#
# - HBP = Home Team Bookings Points (10 = yellow, 25 = red)
#
# - ABP = Away Team Bookings Points (10 = yellow, 25 = red)
#
#
# Note that Free Kicks Conceeded includes fouls, offsides and any other offense commmitted and will always be equal to or higher than the number of fouls.
# Fouls make up the vast majority of Free Kicks Conceded. Free Kicks Conceded are shown when specific data on Fouls are not available (France 2nd, Belgium 1st and Greece 1st divisions).
#
# Note also that English and Scottish yellow cards do not include the initial yellow card when a second is shown to a player converting it into a red, but this is included as a yellow (plus red) for European games.

# %% [markdown]
# # Dropping unneeded columns
# - These include columns involving betting, and the time games are played as this is a column not consistent within all tables

# %%
Season2223.drop(['Div','Time','B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','PSH','PSD','PSA','WHH','WHD','WHA','VCH','VCD','VCA','MaxH','MaxD','MaxA','AvgH','AvgD','AvgA','B365>2.5','B365<2.5','P>2.5','P<2.5','Max>2.5','Max<2.5','Avg>2.5','Avg<2.5','AHh','B365AHH','B365AHA','PAHH','PAHA','MaxAHH','MaxAHA','AvgAHH','AvgAHA','B365CH','B365CD','B365CA','BWCH','BWCD','BWCA','IWCH','IWCD','IWCA','PSCH','PSCD','PSCA','WHCH','WHCD','WHCA','VCCH','VCCD','VCCA','MaxCH','MaxCD','MaxCA','AvgCH','AvgCD','AvgCA','B365C>2.5','B365C<2.5','PC>2.5','PC<2.5','MaxC>2.5','MaxC<2.5','AvgC>2.5','AvgC<2.5','AHCh','B365CAHH','B365CAHA','PCAHH','PCAHA','MaxCAHH','MaxCAHA', 'AvgCAHH', 'AvgCAHA' ], axis=1, inplace=True)

# %%
Season22231.drop(['Div','Time','B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','PSH','PSD','PSA','WHH','WHD','WHA','VCH','VCD','VCA','MaxH','MaxD','MaxA','AvgH','AvgD','AvgA','B365>2.5','B365<2.5','P>2.5','P<2.5','Max>2.5','Max<2.5','Avg>2.5','Avg<2.5','AHh','B365AHH','B365AHA','PAHH','PAHA','MaxAHH','MaxAHA','AvgAHH','AvgAHA','B365CH','B365CD','B365CA','BWCH','BWCD','BWCA','IWCH','IWCD','IWCA','PSCH','PSCD','PSCA','WHCH','WHCD','WHCA','VCCH','VCCD','VCCA','MaxCH','MaxCD','MaxCA','AvgCH','AvgCD','AvgCA','B365C>2.5','B365C<2.5','PC>2.5','PC<2.5','MaxC>2.5','MaxC<2.5','AvgC>2.5','AvgC<2.5','AHCh','B365CAHH','B365CAHA','PCAHH','PCAHA','MaxCAHH','MaxCAHA', 'AvgCAHH', 'AvgCAHA' ], axis=1, inplace=True)

# %%
Season2223['Season']='Season 22/23'

# %%
Season22231['Season']='Season 22/23'

# %%
Season2223.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      77 non-null     object
#  1   HomeTeam  77 non-null     object
#  2   AwayTeam  77 non-null     object
#  3   FTHG      77 non-null     int64
#  4   FTAG      77 non-null     int64
#  5   FTR       77 non-null     object
#  6   HTHG      77 non-null     int64
#  7   HTAG      77 non-null     int64
#  8   HTR       77 non-null     object
#  9   Referee   77 non-null     object
#  10  HS        77 non-null     int64
#  11  AS        77 non-null     int64
#  12  HST       77 non-null     int64
#  13  AST       77 non-null     int64
#  14  HF        77 non-null     int64
#  15  AF        77 non-null     int64
#  16  HC        77 non-null     int64
#  17  AC        77 non-null     int64
#  18  HY        77 non-null     int64
#  19  AY        77 non-null     int64
# ...

# %%
Season2223.head()
# Out:
#          Date        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR        Season
# 0  05/08/2022  Crystal Palace        Arsenal     0     2   A     0     1   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0  Season 22/23
# 1  06/08/2022          Fulham      Liverpool     2     2   D     1     0   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  Season 22/23
# 2  06/08/2022     Bournemouth    Aston Villa     2     0   H     1     0   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0  Season 22/23
# 3  06/08/2022           Leeds         Wolves     2     1   H     1     1   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0  Season 22/23
# 4  06/08/2022       Newcastle  Nott'm Forest     2     0   H     0     0   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0  Season 22/23

# %%
Season2122.drop(['Div','Time','B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','PSH','PSD','PSA','WHH','WHD','WHA','VCH','VCD','VCA','MaxH','MaxD','MaxA','AvgH','AvgD','AvgA','B365>2.5','B365<2.5','P>2.5','P<2.5','Max>2.5','Max<2.5','Avg>2.5','Avg<2.5','AHh','B365AHH','B365AHA','PAHH','PAHA','MaxAHH','MaxAHA','AvgAHH','AvgAHA','B365CH','B365CD','B365CA','BWCH','BWCD','BWCA','IWCH','IWCD','IWCA','PSCH','PSCD','PSCA','WHCH','WHCD','WHCA','VCCH','VCCD','VCCA','MaxCH','MaxCD','MaxCA','AvgCH','AvgCD','AvgCA','B365C>2.5','B365C<2.5','PC>2.5','PC<2.5','MaxC>2.5','MaxC<2.5','AvgC>2.5','AvgC<2.5','AHCh','B365CAHH','B365CAHA','PCAHH','PCAHA','MaxCAHH','MaxCAHA', 'AvgCAHH', 'AvgCAHA' ], axis=1, inplace=True)

# %%
Season2122.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      380 non-null    object
#  1   HomeTeam  380 non-null    object
#  2   AwayTeam  380 non-null    object
#  3   FTHG      380 non-null    int64
#  4   FTAG      380 non-null    int64
#  5   FTR       380 non-null    object
#  6   HTHG      380 non-null    int64
#  7   HTAG      380 non-null    int64
#  8   HTR       380 non-null    object
#  9   Referee   380 non-null    object
#  10  HS        380 non-null    int64
#  11  AS        380 non-null    int64
#  12  HST       380 non-null    int64
#  13  AST       380 non-null    int64
#  14  HF        380 non-null    int64
#  15  AF        380 non-null    int64
#  16  HC        380 non-null    int64
#  17  AC        380 non-null    int64
#  18  HY        380 non-null    int64
#  19  AY        380 non-null    int64
# ...

# %%
Season2122['Season']='Season 21/22'

# %%
Season2122.head()
# Out:
#          Date    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR    Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR        Season
# 0  13/08/2021   Brentford         Arsenal     2     0   H     1     0   H   M Oliver   8  22    3    4  12   8   2   5   0   0   0   0  Season 21/22
# 1  14/08/2021  Man United           Leeds     5     1   H     1     0   H  P Tierney  16  10    8    3  11   9   5   4   1   2   0   0  Season 21/22
# 2  14/08/2021     Burnley        Brighton     1     2   A     1     0   H    D Coote  14  14    3    8  10   7   7   6   2   1   0   0  Season 21/22
# 3  14/08/2021     Chelsea  Crystal Palace     3     0   H     2     0   H     J Moss  13   4    6    1  15  11   5   2   0   0   0   0  Season 21/22
# 4  14/08/2021     Everton     Southampton     3     1   H     0     1   A   A Madley  14   6    6    3  13  15   6   8   2   0   0   0  Season 21/22

# %%
Season2021.drop(['Div','Time','B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','PSH','PSD','PSA','WHH','WHD','WHA','VCH','VCD','VCA','MaxH','MaxD','MaxA','AvgH','AvgD','AvgA','B365>2.5','B365<2.5','P>2.5','P<2.5','Max>2.5','Max<2.5','Avg>2.5','Avg<2.5','AHh','B365AHH','B365AHA','PAHH','PAHA','MaxAHH','MaxAHA','AvgAHH','AvgAHA','B365CH','B365CD','B365CA','BWCH','BWCD','BWCA','IWCH','IWCD','IWCA','PSCH','PSCD','PSCA','WHCH','WHCD','WHCA','VCCH','VCCD','VCCA','MaxCH','MaxCD','MaxCA','AvgCH','AvgCD','AvgCA','B365C>2.5','B365C<2.5','PC>2.5','PC<2.5','MaxC>2.5','MaxC<2.5','AvgC>2.5','AvgC<2.5','AHCh','B365CAHH','B365CAHA','PCAHH','PCAHA','MaxCAHH','MaxCAHA', 'AvgCAHH', 'AvgCAHA' ], axis=1, inplace=True)

# %%
Season2021['Season']='Season 20/21'

# %%
Season2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      380 non-null    object
#  1   HomeTeam  380 non-null    object
#  2   AwayTeam  380 non-null    object
#  3   FTHG      380 non-null    int64
#  4   FTAG      380 non-null    int64
#  5   FTR       380 non-null    object
#  6   HTHG      380 non-null    int64
#  7   HTAG      380 non-null    int64
#  8   HTR       380 non-null    object
#  9   Referee   380 non-null    object
#  10  HS        380 non-null    int64
#  11  AS        380 non-null    int64
#  12  HST       380 non-null    int64
#  13  AST       380 non-null    int64
#  14  HF        380 non-null    int64
#  15  AF        380 non-null    int64
#  16  HC        380 non-null    int64
#  17  AC        380 non-null    int64
#  18  HY        380 non-null    int64
#  19  AY        380 non-null    int64
# ...

# %%
Season2021.head()
# Out:
#          Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR        Season
# 0  12/09/2020          Fulham      Arsenal     0     3   A     0     1   A  C Kavanagh   5  13    2    6  12  12   2   3   2   2   0   0  Season 20/21
# 1  12/09/2020  Crystal Palace  Southampton     1     0   H     1     0   H      J Moss   5   9    3    5  14  11   7   3   2   1   0   0  Season 20/21
# 2  12/09/2020       Liverpool        Leeds     4     3   H     3     2   H    M Oliver  22   6    6    3   9   6   9   0   1   0   0   0  Season 20/21
# 3  12/09/2020        West Ham    Newcastle     0     2   A     0     0   D   S Attwell  15  15    3    2  13   7   8   7   2   2   0   0  Season 20/21
# 4  13/09/2020       West Brom    Leicester     0     3   A     0     0   D    A Taylor   7  13    1    7  12   9   2   5   1   1   0   0  Season 20/21

# %%
Season1920.drop(['Div','Time','B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','PSH','PSD','PSA','WHH','WHD','WHA','VCH','VCD','VCA','MaxH','MaxD','MaxA','AvgH','AvgD','AvgA','B365>2.5','B365<2.5','P>2.5','P<2.5','Max>2.5','Max<2.5','Avg>2.5','Avg<2.5','AHh','B365AHH','B365AHA','PAHH','PAHA','MaxAHH','MaxAHA','AvgAHH','AvgAHA','B365CH','B365CD','B365CA','BWCH','BWCD','BWCA','IWCH','IWCD','IWCA','PSCH','PSCD','PSCA','WHCH','WHCD','WHCA','VCCH','VCCD','VCCA','MaxCH','MaxCD','MaxCA','AvgCH','AvgCD','AvgCA','B365C>2.5','B365C<2.5','PC>2.5','PC<2.5','MaxC>2.5','MaxC<2.5','AvgC>2.5','AvgC<2.5','AHCh','B365CAHH','B365CAHA','PCAHH','PCAHA','MaxCAHH','MaxCAHA', 'AvgCAHH', 'AvgCAHA' ], axis=1, inplace=True)

# %%
Season1920['Season']='Season 19/20'

# %%
Season1920.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      380 non-null    object
#  1   HomeTeam  380 non-null    object
#  2   AwayTeam  380 non-null    object
#  3   FTHG      380 non-null    int64
#  4   FTAG      380 non-null    int64
#  5   FTR       380 non-null    object
#  6   HTHG      380 non-null    int64
#  7   HTAG      380 non-null    int64
#  8   HTR       380 non-null    object
#  9   Referee   380 non-null    object
#  10  HS        380 non-null    int64
#  11  AS        380 non-null    int64
#  12  HST       380 non-null    int64
#  13  AST       380 non-null    int64
#  14  HF        380 non-null    int64
#  15  AF        380 non-null    int64
#  16  HC        380 non-null    int64
#  17  AC        380 non-null    int64
#  18  HY        380 non-null    int64
#  19  AY        380 non-null    int64
# ...

# %%
Season1920.head()
# Out:
#          Date        HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR        Season
# 0  09/08/2019       Liverpool           Norwich     4     1   H     4     0   H  M Oliver  15  12    7    5   9   9  11   2   0   2   0   0  Season 19/20
# 1  10/08/2019        West Ham          Man City     0     5   A     0     1   A    M Dean   5  14    3    9   6  13   1   1   2   2   0   0  Season 19/20
# 2  10/08/2019     Bournemouth  Sheffield United     1     1   D     0     0   D  K Friend  13   8    3    3  10  19   3   4   2   1   0   0  Season 19/20
# 3  10/08/2019         Burnley       Southampton     3     0   H     0     0   D   G Scott  10  11    4    3   6  12   2   7   0   0   0   0  Season 19/20
# 4  10/08/2019  Crystal Palace           Everton     0     0   D     0     0   D    J Moss   6  10    2    3  16  14   6   2   2   1   0   1  Season 19/20

# %%
Season1819.drop(['Div','B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','PSH','PSD','PSA','WHH','WHD','WHA','VCH','VCD','VCA','Bb1X2','BbMxH','BbAvH','BbMxD','BbAvD','BbMxA','BbAvA','BbOU','BbMx>2.5','BbAv>2.5','BbMx<2.5','BbAv<2.5','BbAH','BbAHh','BbMxAHH','BbAvAHH','BbMxAHA','BbAvAHA','PSCH','PSCD','PSCA'], axis=1, inplace=True)

# %%
Season1819['Season']='Season 18/19'

# %%
Season1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      380 non-null    object
#  1   HomeTeam  380 non-null    object
#  2   AwayTeam  380 non-null    object
#  3   FTHG      380 non-null    int64
#  4   FTAG      380 non-null    int64
#  5   FTR       380 non-null    object
#  6   HTHG      380 non-null    int64
#  7   HTAG      380 non-null    int64
#  8   HTR       380 non-null    object
#  9   Referee   380 non-null    object
#  10  HS        380 non-null    int64
#  11  AS        380 non-null    int64
#  12  HST       380 non-null    int64
#  13  AST       380 non-null    int64
#  14  HF        380 non-null    int64
#  15  AF        380 non-null    int64
#  16  HC        380 non-null    int64
#  17  AC        380 non-null    int64
#  18  HY        380 non-null    int64
#  19  AY        380 non-null    int64
# ...

# %%
Season1819.head()
# Out:
#          Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR        Season
# 0  10/08/2018    Man United       Leicester     2     1   H     1     0   H  A Marriner   8  13    6    4  11   8   2   5   2   1   0   0  Season 18/19
# 1  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0   H    K Friend  12  10    4    1  11   9   7   4   1   1   0   0  Season 18/19
# 2  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1   A      M Dean  15  10    6    9   9  11   5   5   1   2   0   0  Season 18/19
# 3  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2   A  C Kavanagh   6  13    1    4   9   8   2   5   2   1   0   0  Season 18/19
# 4  11/08/2018     Newcastle       Tottenham     1     2   A     1     2   A  M Atkinson  15  15    2    5  11  12   3   5   2   2   0   0  Season 18/19

# %%
Season1718.drop(['Div','B365H','B365D','B365A','BWH','BWD','BWA','IWH','IWD','IWA','PSH','PSD','PSA','WHH','WHD','WHA','VCH','VCD','VCA','Bb1X2','BbMxH','BbAvH','BbMxD','BbAvD','BbMxA','BbAvA','BbOU','BbMx>2.5','BbAv>2.5','BbMx<2.5','BbAv<2.5','BbAH','BbAHh','BbMxAHH','BbAvAHH','BbMxAHA','BbAvAHA','PSCH','PSCD','PSCA', 'LBH', 'LBD', 'LBA'], axis=1, inplace=True)

# %%
Season1718['Season']='Season 17/18'

# %%
Season1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      380 non-null    object
#  1   HomeTeam  380 non-null    object
#  2   AwayTeam  380 non-null    object
#  3   FTHG      380 non-null    int64
#  4   FTAG      380 non-null    int64
#  5   FTR       380 non-null    object
#  6   HTHG      380 non-null    int64
#  7   HTAG      380 non-null    int64
#  8   HTR       380 non-null    object
#  9   Referee   380 non-null    object
#  10  HS        380 non-null    int64
#  11  AS        380 non-null    int64
#  12  HST       380 non-null    int64
#  13  AST       380 non-null    int64
#  14  HF        380 non-null    int64
#  15  AF        380 non-null    int64
#  16  HC        380 non-null    int64
#  17  AC        380 non-null    int64
#  18  HY        380 non-null    int64
#  19  AY        380 non-null    int64
# ...

# %%
Season1718.head()
# Out:
#          Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR      Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR        Season
# 0  11/08/2017         Arsenal     Leicester     4     3   H     2     2   D       M Dean  27   6   10    3   9  12   9   4   0   1   0   0  Season 17/18
# 1  12/08/2017        Brighton      Man City     0     2   A     0     0   D     M Oliver   6  14    2    4   6   9   3  10   0   2   0   0  Season 17/18
# 2  12/08/2017         Chelsea       Burnley     2     3   A     0     3   A     C Pawson  19  10    6    5  16  11   8   5   3   3   2   0  Season 17/18
# 3  12/08/2017  Crystal Palace  Huddersfield     0     3   A     0     2   A       J Moss  14   8    4    6   7  19  12   9   1   3   0   0  Season 17/18
# 4  12/08/2017         Everton         Stoke     1     0   H     1     0   H  N Swarbrick   9   9    4    1  13  10   6   7   1   1   0   0  Season 17/18

# %% [markdown]
# # Merging the datasets together
#
# - Now that the datasets have all of the same variables, and have an added column indicating the season the matches were played in, they can be merged together to create one larger dataset

# %%
df = pd.concat([Season22231, Season2122, Season2021, Season1920, Season1819, Season1718], axis=0)

# %%
df.head()
# Out:
#          Date        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR        Season
# 0  05/08/2022  Crystal Palace        Arsenal     0     2   A     0     1   A  A Taylor  10  10    2    2  16  11   3   5   1   2   0   0  Season 22/23
# 1  06/08/2022          Fulham      Liverpool     2     2   D     1     0   H  A Madley   9  11    3    4   7   9   4   4   2   0   0   0  Season 22/23
# 2  06/08/2022     Bournemouth    Aston Villa     2     0   H     1     0   H  P Bankes   7  15    3    2  18  16   5   5   3   3   0   0  Season 22/23
# 3  06/08/2022           Leeds         Wolves     2     1   H     1     1   D   R Jones  12  15    4    6  13   9   6   4   2   0   0   0  Season 22/23
# 4  06/08/2022       Newcastle  Nott'm Forest     2     0   H     0     0   D  S Hooper  23   5   10    0   9  14  11   1   0   3   0   0  Season 22/23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2016 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2016 non-null   object
#  1   HomeTeam  2016 non-null   object
#  2   AwayTeam  2016 non-null   object
#  3   FTHG      2016 non-null   int64
#  4   FTAG      2016 non-null   int64
#  5   FTR       2016 non-null   object
#  6   HTHG      2016 non-null   int64
#  7   HTAG      2016 non-null   int64
#  8   HTR       2016 non-null   object
#  9   Referee   2016 non-null   object
#  10  HS        2016 non-null   int64
#  11  AS        2016 non-null   int64
#  12  HST       2016 non-null   int64
#  13  AST       2016 non-null   int64
#  14  HF        2016 non-null   int64
#  15  AF        2016 non-null   int64
#  16  HC        2016 non-null   int64
#  17  AC        2016 non-null   int64
#  18  HY        2016 non-null   int64
#  19  AY        2016 non-null   int64
# ...

# %% [markdown]
# The datasets have now been merged into 'df', and has been checked to have the correct amount of variables using the ".info" statement. (All 5 complete seasons = 1900 datapoints, and the incomplete 22/23 season with 77 variables).

# %%
df.to_csv('premierleague.csv')

# %%
df.to_csv('/Users/eveobrien/Desktop/premierleague.csv')

# %% [markdown]
# # Renaming features
#
# - Most of the features have names that are difficult to interpret, the .rename function will be used to solve this problem.

# %%
df.rename(columns = {'FTHG':'FullTime Home Goals', 'FTAG':'FullTime Away Goals', 'FTR':'FullTime Result',
                    'HTHG':'HalfTime Home Goals', 'HTAG':'HalfTime Away Goals',
                    'HTR': 'HalfTime Result', 'HS':'HomeTeam Shots', 'AS':'AwayTeam Shots',
                    'HST':'HomeTeam Shots on Target', 'AST':'AwayTeam Shots on Target',
                    'HC':'HomeTeam Corners', 'AC':'AwayTeam Corners',
                    'HY':'HomeTeam Yellow Cards', 'AY':'AwayTeam Yellow Cards',
                    'HR':'HomeTeam Red Cards', 'AR':'AwayTeam Red Cards',
                    'HF':'HomeTeam Fouls Committed', 'AF':'AwayTeam Fouls Committed'}, inplace = True)

# %%
df['FullTime Result'].replace('H','Home Win',inplace=True)
df['FullTime Result'].replace('A','Away Win',inplace=True)
df['FullTime Result'].replace('D','Draw',inplace=True)

# %%
df['HalfTime Result'].replace('H','Home Win',inplace=True)
df['HalfTime Result'].replace('A','Away Win',inplace=True)
df['HalfTime Result'].replace('D','Draw',inplace=True)

# %%
df.head()
# Out:
#          Date        HomeTeam       AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result   Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season
# 0  05/08/2022  Crystal Palace        Arsenal                    0                    2        Away Win                    0                    1        Away Win  A Taylor              10              10                         2                         2                        16                        11                 3                 5                      1                      2                   0                   0  Season 22/23
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df['GoalMargin']=df['FullTime Home Goals']-df['FullTime Away Goals']

# %%
df.head()
# Out:
#          Date        HomeTeam       AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result   Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season  GoalMargin
# 0  05/08/2022  Crystal Palace        Arsenal                    0                    2        Away Win                    0                    1        Away Win  A Taylor              10              10                         2                         2                        16                        11                 3                 5                      1                      2                   0                   0  Season 22/23          -2
# ...

# %% [markdown]
# 29 different teams have competed in the Premier League over the last 5 years.

# %%
df['HomeTeam'].nunique()
# Out:
# 29

# %% [markdown]
# This demonstrates that teams that play in their home stadium have an edge. Every time a game was played, there was a 44% chance that the home team would win, a 33% chance that the away club would prevail, and a 23% chance that both teams would draw.

# %%
round(df['FullTime Result'].value_counts(normalize=True)*100,0)
# Out:
# Home Win    44.0
# Away Win    33.0
# Draw        23.0
# Name: FullTime Result, dtype: float64

# %%
df[df['GoalMargin']==df['GoalMargin'].max()]
# Out:
#            Date    HomeTeam     AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result    Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season  GoalMargin
# 34   27/08/2022   Liverpool  Bournemouth                    9                    0        Home Win                    5                    0        Home Win  S Attwell              19               5                        12                         2                         6                         5                 8                 1                      0                      1                   0                   0  Season 22/23           9
# ...

# %% [markdown]
# This shows that Liverpool and Man Utd had the biggest goal margin (9-0 respectively), dealing Bournemouth and Southampton the biggest losses over the last five years

# %%
df[df['FullTime Home Goals']==df['FullTime Home Goals'].max()].sort_values('GoalMargin', ascending =False).tail()
# Out:
#            Date    HomeTeam     AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result    Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season  GoalMargin
# 34   27/08/2022   Liverpool  Bournemouth                    9                    0        Home Win                    5                    0        Home Win  S Attwell              19               5                        12                         2                         6                         5                 8                 1                      0                      1                   0                   0  Season 22/23           9
# ...

# %% [markdown]
# This shows that again, the same matches between the teams shows that Liverpool and Man Utd had the biggest home wins over the last five years

# %%
df[df['FullTime Away Goals']==df['FullTime Away Goals'].max()].sort_values('GoalMargin', ascending =False).tail()
# Out:
#           Date     HomeTeam   AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result     Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season  GoalMargin
# 90  25/10/2019  Southampton  Leicester                    0                    9        Away Win                    0                    5        Away Win  A Marriner               6              25                         3                        15                         3                        12                 2                 7                      0                      0                   1                   0  Season 19/20          -9

# %% [markdown]
# This shows that Leicester had the biggest Away win over the last five years

# %% [markdown]
# # Premier League Dataset 1992-2022

# %%
pl_df = pd.read_csv("epl.csv")

# %%
pl_df.head()
# Out:
#    Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals            Away FTR
# 0             1993   1  1992-08-15   Coventry City          2          1   Middlesbrough   H
# 1             1993   1  1992-08-15    Leeds United          2          1       Wimbledon   H
# 2             1993   1  1992-08-15   Sheffield Utd          2          1  Manchester Utd   H
# 3             1993   1  1992-08-15  Crystal Palace          3          3       Blackburn   D
# 4             1993   1  1992-08-15         Arsenal          2          4    Norwich City   A

# %% [markdown]
# - This won't be used until later.

# %% [markdown]
# Created a new column with a default value of 3points, since home win and away win equals points.Then use the '.ioc' to filter the the rows and assign 1point to draw fixtures.

# %%
df['Point']= 3
df.loc[df['FullTime Result']=='Draw','Point']=1

# %%
df['Point'] = df['Point'].fillna(0)

# %%
df.head()
# Out:
#          Date        HomeTeam       AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result   Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season  GoalMargin  Point
# 0  05/08/2022  Crystal Palace        Arsenal                    0                    2        Away Win                    0                    1        Away Win  A Taylor              10              10                         2                         2                        16                        11                 3                 5                      1                      2                   0                   0  Season 22/23          -2      3
# ...

# %%
df.pivot_table('Point','HomeTeam',aggfunc='sum').sort_values('Point', ascending =False).head()
# Out:
#            Point
# HomeTeam
# Man City     287
# Tottenham    277
# Arsenal      266
# Liverpool    265
# Leicester    263

# %% [markdown]
# The team with the most points at home was Manchester City. The teams that have accrued the most points when playing at home are Manchester City Tottenham, Arsenal, Leicester, and Liverpool.

# %%
df.pivot_table('Point','HomeTeam',aggfunc='sum').sort_values('Point', ascending =False).tail()
# Out:
#                Point
# HomeTeam
# Brentford         65
# Cardiff           53
# Swansea           51
# Stoke             47
# Nott'm Forest     16

# %% [markdown]
# The team with the fewest points when playing at home is Nottingham Forest. While the top 5 teams with the lowest home point totals are Nott'm Forest, Stoke, Swansea, Cardiff, and Brentford.

# %%
df.pivot_table('Point','AwayTeam',aggfunc='sum').sort_values('Point', ascending =False).head()
# Out:
#            Point
# AwayTeam
# Man City     272
# Chelsea      267
# Arsenal      261
# West Ham     259
# Tottenham    257

# %% [markdown]
# The team with the most points playing away from home is Chelsea. While the top 5 teams that have accrued the most points while playing away from home are Manchester City, Chelsea, Arsenal, West Ham, and Tottenham.

# %%
df.pivot_table('Point','AwayTeam',aggfunc='sum').sort_values('Point', ascending =False).tail()
# Out:
#                Point
# AwayTeam
# Brentford         61
# Cardiff           53
# Swansea           45
# Stoke             43
# Nott'm Forest     14

# %% [markdown]
# The team with the least points playing away from home is Nott'm Forest. While the top 5 teams that have accrued the most points while playing away from home are Nott'm Forest, Stoke, Swansea, Cardiff,and Brentford.

# %%
df.pivot_table('Point','FullTime Result', aggfunc=sum).sort_values('Point', ascending =False)
# Out:
#                  Point
# FullTime Result
# Home Win          2676
# Away Win          1980
# Draw               464

# %%
round(df.pivot_table('Point','FullTime Result', aggfunc=sum).div(sum(df['Point'])).mul(100).sort_values('Point', ascending =False))
# Out:
#                  Point
# FullTime Result
# Home Win          52.0
# Away Win          39.0
# Draw               9.0

# %% [markdown]
# In the past 5 years of the English Premier League, teams that played at home gathered 2610 (52%) points, while those that played away from home amassed 1956 (39%) points. Matches that were drawn accrued 455 (9)% of the total points. This supports the idea of home team advantage.

# %%
Home=df.pivot_table('Point','HomeTeam',columns='FullTime Result',aggfunc=sum).sort_values('Home Win', ascending =False)
rem=Home.drop(['Away Win'],axis=1)
rem['Total_Home_Point']=Home['Draw']+Home['Home Win']
rem.head()
# Out:
# FullTime Result  Draw  Home Win  Total_Home_Point
# HomeTeam
# Man City            8       249               257
# Liverpool          19       228               247
# Tottenham          13       195               208
# Arsenal            17       195               212
# Man United         25       171               196

# %% [markdown]
# Man City have accured the most points at home, followed by Liverpool, Tottenham, Arsenal and Man Utd.

# %%
Home=df.pivot_table('Point','HomeTeam',columns='FullTime Result',aggfunc=sum).sort_values('Home Win', ascending =False)
rem=Home.drop(['Away Win'],axis=1)
rem['Total_Home_Point']=Home['Draw']+Home['Home Win']
rem.tail()
# Out:
# FullTime Result  Draw  Home Win  Total_Home_Point
# HomeTeam
# Swansea             3        18                21
# West Brom          15        18                33
# Cardiff             2        18                20
# Stoke               5        15                20
# Nott'm Forest       1         6                 7

# %%
Home=df.pivot_table('Point','HomeTeam',columns='FullTime Result',aggfunc=sum).sort_values('Home Win', ascending =False)
rem=Home.drop(['Draw','Home Win'],axis=1)
rem.rename(columns={'Away Win':'Lost Home Points'}).sort_values('Lost Home Points', ascending =False).head()
# Out:
# FullTime Result  Lost Home Points
# HomeTeam
# Burnley                       123
# Southampton                   120
# Crystal Palace                114
# Watford                       108
# Newcastle                     105

# %% [markdown]
# Over the past 5 years, Burnley have dropped the most points at Home in the Premier League, with Newcastle in 5th place

# %%
Away=df.pivot_table('Point','AwayTeam',columns='FullTime Result',aggfunc=sum).sort_values('Away Win', ascending =False)
rem=Away.drop(['Home Win'],axis=1)
rem['Total_Away_Point']=rem['Draw']+rem['Away Win']
rem.head()
# Out:
# FullTime Result  Away Win  Draw  Total_Away_Point
# AwayTeam
# Man City            213.0  14.0             227.0
# Liverpool           177.0  24.0             201.0
# Chelsea             159.0  18.0             177.0
# Man United          144.0  25.0             169.0
# Tottenham           132.0  23.0             155.0

# %% [markdown]
# Over the last 5 years, Man City accumulated the most points away from home

# %%
Away=df.pivot_table('Point','AwayTeam',columns='FullTime Result',aggfunc=sum).sort_values('Away Win', ascending =False)
rem=Away.drop(['Home Win'],axis=1)
rem['Total_Away_Point']=rem['Draw']+rem['Away Win']
rem.tail()
# Out:
# FullTime Result  Away Win  Draw  Total_Away_Point
# AwayTeam
# Cardiff              12.0   2.0              14.0
# Norwich               9.0   7.0              16.0
# Stoke                 6.0   7.0              13.0
# Swansea               6.0   6.0              12.0
# Nott'm Forest         NaN   2.0               NaN

# %% [markdown]
# Nottingham Forest accumulated the least points, 0 away from home.

# %%
Away=df.pivot_table('Point','AwayTeam',columns='FullTime Result',aggfunc=sum).sort_values('Away Win', ascending =False)
rem=Away.drop(['Draw','Away Win'],axis=1)
rem.rename(columns={'Home Win':'Lost Away Points'}).sort_values('Lost Away Points', ascending =False).head()
# Out:
# FullTime Result  Lost Away Points
# AwayTeam
# Everton                     150.0
# Southampton                 150.0
# Newcastle                   147.0
# West Ham                    147.0
# Brighton                    144.0

# %% [markdown]
# In the past five years, Everton lost the most points when playing away.

# %%
Home=df.pivot_table('Point',['Season','HomeTeam'],columns='FullTime Result',aggfunc=sum)
rem=Home.drop(['Away Win'],axis=1)
rem['Total_Home_Point']=Home['Draw']+Home['Home Win']
rem.sort_values('Total_Home_Point', ascending =False).head(40)
# Out:
# FullTime Result                Draw  Home Win  Total_Home_Point
# Season       HomeTeam
# Season 19/20 Liverpool          1.0      54.0              55.0
# Season 18/19 Liverpool          2.0      51.0              53.0
# Season 17/18 Man City           2.0      48.0              50.0
# Season 21/22 Liverpool          4.0      45.0              49.0
# Season 17/18 Arsenal            2.0      45.0              47.0
# Season 21/22 Man City           2.0      45.0              47.0
# Season 19/20 Man City           2.0      45.0              47.0
# Season 17/18 Man United         2.0      45.0              47.0
# Season 18/19 Arsenal            3.0      42.0              45.0
# Season 17/18 Liverpool          7.0      36.0              43.0
#              Tottenham          4.0      39.0              43.0
# Season 18/19 Chelsea            6.0      36.0              42.0
# Season 21/22 Arsenal            2.0      39.0              41.0
# ...

# %% [markdown]
# Total points amassed by team playing at home in the epl by season last 5 seasons. Playing at home over different seasons, Liverpool amassed 55 points, which is the highest points earned by any team playing at home.

# %%
Away=df.pivot_table('Point',['Season','AwayTeam'],columns='FullTime Result',aggfunc=sum)
rem=Away.drop(['Home Win'],axis=1)
rem['Total_Away_Point']=Away['Draw']+Away['Away Win']
rem.sort_values('Total_Away_Point', ascending =False).head(40)
# Out:
# FullTime Result              Away Win  Draw  Total_Away_Point
# Season       AwayTeam
# Season 17/18 Man City            48.0   2.0              50.0
# Season 21/22 Man City            42.0   4.0              46.0
# Season 20/21 Man City            42.0   3.0              45.0
# Season 19/20 Liverpool           42.0   2.0              44.0
# Season 18/19 Man City            42.0   2.0              44.0
#              Liverpool           39.0   5.0              44.0
# Season 21/22 Liverpool           39.0   4.0              43.0
# Season 20/21 Man United          36.0   7.0              43.0
# Season 21/22 Chelsea             36.0   4.0              40.0
# Season 20/21 Leicester           33.0   5.0              38.0
#              Everton             33.0   4.0              37.0
#              Liverpool           30.0   6.0              36.0
#              Chelsea             30.0   4.0              34.0
# Season 17/18 Man United          30.0   4.0              34.0
# ...

# %% [markdown]
# Total points amassed by team playing at away in the epl by season last 5 years. Manchester City had the highest points (50) playing away in the 2017/2018 season.

# %%
Away=df.pivot_table('Point',['Season','AwayTeam'],columns='FullTime Result',aggfunc=sum)
rem=Away.drop(['Home Win'],axis=1)
rem['Total_Away_Point']=Away['Draw']+Away['Away Win']
rem['Total_Home_Point']=Home['Draw']+Home['Home Win']
rem['Total_Point']=rem['Total_Away_Point']+rem['Total_Home_Point']
rem.sort_values('Total_Point', ascending =False).head(50)
# Out:
# FullTime Result                Away Win  Draw  Total_Away_Point  Total_Home_Point  Total_Point
# Season       AwayTeam
# Season 17/18 Man City              48.0   2.0              50.0              50.0        100.0
# Season 19/20 Liverpool             42.0   2.0              44.0              55.0         99.0
# Season 18/19 Liverpool             39.0   5.0              44.0              53.0         97.0
# Season 21/22 Man City              42.0   4.0              46.0              47.0         93.0
#              Liverpool             39.0   4.0              43.0              49.0         92.0
# Season 20/21 Man City              42.0   3.0              45.0              41.0         86.0
# Season 17/18 Man United            30.0   4.0              34.0              47.0         81.0
# Season 19/20 Man City              33.0   1.0              34.0              47.0         81.0
# Season 17/18 Tottenham             30.0   4.0              34.0              43.0         77.0
# ...

# %% [markdown]
# EPL teams' cumulative points per last 5 years, broken down by season. Manchester City won the epl with the most points scored (100) in a single season

# %%
df.pivot_table('FullTime Home Goals','Season',aggfunc=sum).sort_values('FullTime Home Goals', ascending =False).head()
# Out:
#               FullTime Home Goals
# Season
# Season 18/19                  596
# Season 17/18                  582
# Season 19/20                  576
# Season 21/22                  575
# Season 20/21                  514

# %% [markdown]
# Season 18/19 has had the most goals over the last 5 seasons

# %%
df.pivot_table('FullTime Away Goals','Season',aggfunc=sum).sort_values('FullTime Away Goals', ascending =False).head()
# Out:
#               FullTime Away Goals
# Season
# Season 20/21                  510
# Season 21/22                  496
# Season 18/19                  476
# Season 19/20                  458
# Season 17/18                  436

# %%
def get_count(col, title, top):
    if top == 0:
        d = pd.DataFrame(df[col].value_counts())
    else:
         d = pd.DataFrame(df[col].value_counts().head(top))
    d = d.reset_index()
    d = d.rename(columns={'index' : col , col : 'count'})
    d.sort_values('count', ascending=False)
    return px.bar(data_frame=d, x= col, y='count' , title= title, text_auto=True)

# %%
df.head()
# Out:
#          Date        HomeTeam       AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result   Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season  GoalMargin  Point
# 0  05/08/2022  Crystal Palace        Arsenal                    0                    2        Away Win                    0                    1        Away Win  A Taylor              10              10                         2                         2                        16                        11                 3                 5                      1                      2                   0                   0  Season 22/23          -2      3
# ...

# %%
get_count('Referee', 'Top 20 Referee appearances ',20)
# Out:
# <div>                            <div id="df4bafb3-f83e-420a-ae3b-423f261d53ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df4bafb3-f83e-420a-ae3b-423f261d53ac")) {                    Plotly.newPlot(                        "df4bafb3-f83e-420a-ae3b-423f261d53ac",                        [{"alignmentgroup":"True","hovertemplate":"Referee=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["A Taylor","M Oliver","M Atkinson","M Dean","J Moss","C Pawson","A Marriner","P Tierney","K Friend","C Kavanagh","S Attwell","G Scott","D Coote","L Mason","S Hooper","A Madley","P Bankes","D England",
# ...

# %%
##### To categorizing the result of each match into home team won, the away team won, or drew:
df['Result'] = np.where(df['FullTime Result'] == 'Home Win','HomeTeamWin', np.where(df['FullTime Result'] == 'Away Win', 'AwayTeamWin', "Draw"))

##### Now identify the winner of each match: 
# if "H"- the home team was the winner, if "A" the away team was the winner, else draw:
df['Winner'] = np.where(df['FullTime Result'] == 'Home Win',df['HomeTeam'], np.where(df['FullTime Result'] == 'Away Win', df['AwayTeam'], "Draw"))

##### To identify how many goals did the winner had:
df['WinnerGoals'] = np.where(df['FullTime Result'] == 'Home Win',df['FullTime Home Goals'], np.where(df['FullTime Result'] == 'Away Win', df['FullTime Away Goals'], df['FullTime Home Goals']))

##### To get the total number of goals in each match and the goal differences:
df['TotalGoal'] = df['FullTime Home Goals'] + df['FullTime Away Goals']
df['GoalDif']= df['FullTime Home Goals']- df['FullTime Away Goals']

##### Creating a separate Home and Away points table for Points per Goal analysis for each match
df['HG_points'] = np.where(df['Result'] == 'HomeTeamWin',3, np.where(df['Result'] == 'AwayTeamWin', 0, 1))
df['AG_points'] = np.where(df['Result'] == 'HomeTeamWin',0, np.where(df['Result'] == 'AwayTeamWin', 3, 1))

# %%
df.head()
# Out:
#          Date        HomeTeam       AwayTeam  FullTime Home Goals  FullTime Away Goals FullTime Result  HalfTime Home Goals  HalfTime Away Goals HalfTime Result   Referee  HomeTeam Shots  AwayTeam Shots  HomeTeam Shots on Target  AwayTeam Shots on Target  HomeTeam Fouls Committed  AwayTeam Fouls Committed  HomeTeam Corners  AwayTeam Corners  HomeTeam Yellow Cards  AwayTeam Yellow Cards  HomeTeam Red Cards  AwayTeam Red Cards        Season  GoalMargin  Point       Result       Winner  WinnerGoals  TotalGoal  GoalDif  HG_points  AG_points
# ...

# %%
##### As per teams point of view
total_matches = len(df['Result'])
home_win_per = round((df[df.Result =='HomeTeamWin'].count()[0]/total_matches)*100,3)
away_win_per = round((df[df.Result =='AwayTeamWin'].count()[0]/total_matches)*100,3)
draw_matches = round((df[df.Result =='Draw'].count()[0]/total_matches)*100,3)

# Create a pie plot for better Visualization
plt.rcParams['figure.figsize'] = [19, 8]
names = ['Home Win', 'Away Win', 'Draw']
complied_data = home_win_per, away_win_per, draw_matches

# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

# Custom wedges
plt.pie(complied_data, labels=names, wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' }, autopct="%.1f%%")
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# The chart shows the 'Home Team' wins 44% of the time, 'Away Team' wins 33%, and a Draw occurs 22% of the time.

# %%
##### Average goal scored in a Home vs Away Fixtures

plt.rcParams['figure.figsize'] = [5, 5]
fixtures = 'Home','Away'
avg_goals = df['FullTime Home Goals'].mean(), df['FullTime Away Goals'].mean()

plt.bar(fixtures, avg_goals, color ='royalblue', width = 0.2)
plt.xlabel("Fixture")
plt.ylabel("Average Goal Scored")
plt.title("Average goal scored in a Home vs Away Fixtures")
plt.show()

# %%
home_goal_rate = df.groupby('HomeTeam').mean()['FullTime Home Goals'].reset_index().rename(columns={'HomeTeam':'Teams'})
# Avg Goal scored by top 5 teams while playing in Home Condition 
away_goal_rate = df.groupby('AwayTeam').mean()['FullTime Away Goals'].reset_index().rename(columns={'AwayTeam':'Teams'})
# Now Joing the table
avg_goal = home_goal_rate.merge(away_goal_rate, how ='right', on='Teams').sort_values(by=['FullTime Home Goals',
                                                                                          'FullTime Away Goals'], 
                                                                                      ascending = False, 
                                                                                      ignore_index=True)
avg_goal.head(40)
# Out:
#                Teams  FullTime Home Goals  FullTime Away Goals
# 0           Man City             3.000000             2.180000
# 1          Liverpool             2.445545             1.950000
# 2            Arsenal             2.050000             1.376238
# 3          Tottenham             1.970297             1.613861
# 4         Man United             1.890000             1.544554
# 5            Chelsea             1.770000             1.653465
# 6          Leicester             1.594059             1.623762
# 7           West Ham             1.574257             1.217822
# 8        Aston Villa             1.396825             1.126984
# 9            Everton             1.376238             1.029703
# 10         Brentford             1.360000             1.280000
# 11       Bournemouth             1.301587             1.095238
# 12         Newcastle             1.277228             0.990099
# 13             Leeds             1.250000             1.441860
# ...

# %% [markdown]
# Average number of goals scored for each team past 5 seasons in the EPL

# %%
##### Let’s do some more. What is the average for home and away goals during home and away wins?
new_df = df[['FullTime Home Goals','FullTime Away Goals','Result','HG_points','AG_points']]
avg_goals = new_df.groupby('Result').mean()
avg_goals
# Out:
#              FullTime Home Goals  FullTime Away Goals  HG_points  AG_points
# Result
# AwayTeamWin             0.562121             2.386364        0.0        3.0
# Draw                    0.969828             0.969828        1.0        1.0
# HomeTeamWin             2.495516             0.530269        3.0        0.0

# %% [markdown]
# From all the data and charts above regarding the Win% and Goal Scoring rate we can conclude that the home stadium ground does give advantage to the team and are more likely to score goals at there own turf. When a team plays at Home you can expect 0.15 more goals compared to away games. The chance of winning the game when you play at Home reaches almost 428% compaired to Away games at only 33% respectively.
# As per the above analysis, Even if you win away, the home team will still score more often than not. So you’ll need to score at least 2 most of the time. Same for home wins too, although teams winning at home score slightly less than teams winning away.

# %% [markdown]
# # Utilising the 1992-2022 English Premier League Data

# %%
pl_df.head()
# Out:
#    Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals            Away FTR
# 0             1993   1  1992-08-15   Coventry City          2          1   Middlesbrough   H
# 1             1993   1  1992-08-15    Leeds United          2          1       Wimbledon   H
# 2             1993   1  1992-08-15   Sheffield Utd          2          1  Manchester Utd   H
# 3             1993   1  1992-08-15  Crystal Palace          3          3       Blackburn   D
# 4             1993   1  1992-08-15         Arsenal          2          4    Norwich City   A

# %%
##### To categorizing the result of each match into home team won, the away team won, or drew:
pl_df['Result'] = np.where(pl_df['FTR'] == 'H','HomeTeamWin', np.where(pl_df['FTR'] == 'A', 'AwayTeamWin', "Draw"))

##### Now identify the winner of each match: 
# if "H"- the home team was the winner, if "A" the away team was the winner, else draw:
pl_df['Winner'] = np.where(pl_df['FTR'] == 'H',pl_df['Home'], np.where(pl_df['FTR'] == 'A', pl_df['Away'], "Draw"))

##### To identify how many goals did the winner had:
pl_df['WinnerGoals'] = np.where(pl_df['FTR'] == 'H',pl_df['HomeGoals'], np.where(pl_df['FTR'] == 'A', pl_df['AwayGoals'], pl_df['HomeGoals']))

##### To get the total number of goals in each match and the goal differences:
pl_df['TotalGoal'] = pl_df['HomeGoals'] + pl_df['AwayGoals']
pl_df['GoalDif']= pl_df['HomeGoals']- pl_df['AwayGoals']

##### Creating a saparate Home and Away points table for Points per Goal analysis for each match
pl_df['HG_points'] = np.where(pl_df['Result'] == 'HomeTeamWin',3, np.where(pl_df['Result'] == 'AwayTeamWin', 0, 1))
pl_df['AG_points'] = np.where(pl_df['Result'] == 'HomeTeamWin',0, np.where(pl_df['Result'] == 'AwayTeamWin', 3, 1))

# %%
pl_df.head()
# Out:
#    Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals            Away FTR       Result         Winner  WinnerGoals  TotalGoal  GoalDif  HG_points  AG_points
# 0             1993   1  1992-08-15   Coventry City          2          1   Middlesbrough   H  HomeTeamWin  Coventry City            2          3        1          3          0
# 1             1993   1  1992-08-15    Leeds United          2          1       Wimbledon   H  HomeTeamWin   Leeds United            2          3        1          3          0
# 2             1993   1  1992-08-15   Sheffield Utd          2          1  Manchester Utd   H  HomeTeamWin  Sheffield Utd            2          3        1          3          0
# 3             1993   1  1992-08-15  Crystal Palace          3          3       Blackburn   D         Draw           Draw            3          6        0          1          1
# ...

# %%
# Counting Home Goals scored by All Teams 
home_goal_count = pl_df.groupby(['Home'])['HomeGoals'].sum().reset_index()
home_goal_count.columns = ['index','Home Goals']

# Counting Away Goals scored by All Teams 
away_goal_count = pl_df.groupby(['Away'])['AwayGoals'].sum().reset_index()
away_goal_count.columns = ['index','Away Goals']

##### Merging above dataframes to create a dataframe to know teams who scored most both H & A goals in all fixtures since 1993 season
total_goals_scored = pd.merge(home_goal_count, away_goal_count ,how ='right',on ='index')
total_goals_scored.sort_values(by=['Home Goals','Away Goals'], ascending = False).head()
# Out:
#              index  Home Goals  Away Goals
# 27  Manchester Utd        1214         971
# 25       Liverpool        1156         865
# 0          Arsenal        1154         863
# 14         Chelsea        1121         852
# 43       Tottenham         995         750

# %%
##### Visualise the chart in stack manner of bar type

plt.rcParams['figure.figsize'] = [19, 8]
total_goals_scored.plot(x='index', kind='bar', stacked=True, title='Home vs Away Goal Stacked Bar Graph')
plt.xlabel('Teams')
plt.ylabel('No. of Goals Scored')
plt.show()

# %% [markdown]
# Manchester United have scored the total most amount of goals in EPL history, followed by Liverpool, Arsenal and Chelsea.

# %%
##### As per teams point of view
total_matches = len(pl_df['Result'])
home_win_per = round((pl_df[pl_df.Result =='HomeTeamWin'].count()[0]/total_matches)*100,3)
away_win_per = round((pl_df[pl_df.Result =='AwayTeamWin'].count()[0]/total_matches)*100,3)
draw_matches = round((pl_df[pl_df.Result =='Draw'].count()[0]/total_matches)*100,3)

# Create a pie plot for better Visualization
plt.rcParams['figure.figsize'] = [19, 8]
names = ['Home Win', 'Away Win', 'Draw']
complied_data = home_win_per, away_win_per, draw_matches

# Create a circle at the center of the plot
my_circle = plt.Circle( (0,0), 0.7, color='white')

# Custom wedges
plt.pie(complied_data, labels=names, wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' }, autopct="%.1f%%")
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# Throughout the history of the EPL, 46% of games the Home team wins, 29% the away team wins, and 26% is a draw.

# %%
##### Average goal scored in a Home vs Away Fixtures

plt.rcParams['figure.figsize'] = [5, 5]
fixtures = 'Home','Away'
avg_goals = pl_df['HomeGoals'].mean(), pl_df['AwayGoals'].mean()

plt.bar(fixtures, avg_goals, color ='royalblue', width = 0.2)
plt.xlabel("Fixture")
plt.ylabel("Average Goal Scored")
plt.title("Average goal scored in a Home vs Away Fixtures")
plt.show()

# %%
# Avg Goal scored by top 5 teams while playing in Home Condition 
home_goal_rate = pl_df.groupby('Home').mean()['HomeGoals'].reset_index().rename(columns={'Home':'Teams'})
# Avg Goal scored by top 5 teams while playing in Home Condition 
away_goal_rate = pl_df.groupby('Away').mean()['AwayGoals'].reset_index().rename(columns={'Away':'Teams'})
# Now Joing the table
avg_goal = home_goal_rate.merge(away_goal_rate, how ='right', on='Teams').sort_values(by=['HomeGoals',
                                                                                          'AwayGoals'], 
                                                                                      ascending = False, 
                                                                                      ignore_index=True)
avg_goal.head()
# Out:
#              Teams  HomeGoals  AwayGoals
# 0   Manchester Utd   2.107639   1.685764
# 1        Liverpool   2.006944   1.501736
# 2          Arsenal   2.003472   1.498264
# 3  Manchester City   1.989605   1.457380
# 4          Chelsea   1.946181   1.479167

# %% [markdown]
# Man Utd have the highest average of goals scored.

# %%
avg_goal.tail()
# Out:
#              Teams  HomeGoals  AwayGoals
# 45        Brighton   1.094737   0.905263
# 46  Crystal Palace   1.079681   1.099602
# 47    Cardiff City   1.078947   0.657895
# 48         Burnley   1.059211   0.914474
# 49    Huddersfield   0.684211   0.631579

# %% [markdown]
# Huddersfield have the lowest average of goals scored.

# %% [markdown]
# Match Section

# %%
##### Number of season played by teams

season_played = pl_df.groupby(['Home'])['Season_End_Year'].nunique().reset_index(name ='Seasons'
                                                                                ).rename(columns={'Home':'index'})

##### Let`s Calculate the Total Matches Played by all Teams in between 1993-2022 Season
home_matches = pl_df['Home'].value_counts()
away_matches = pl_df['Away'].value_counts()
total_matches_played = (home_matches + away_matches).reset_index(name = 'Matches Played')


##### Let`s Calculate the Number matches Won by teams
team_result = pl_df.groupby('Winner')['Winner'].count().reset_index(name = "Won")
# Drop the results which were "Draw" as this data is not required
matches_won = team_result[team_result.Winner != 'Draw'].rename(columns={'Winner':'index'})


##### Same for the Total Matches Drawn in both AWAY and HOME fixtures combined
away_matches_draw = pl_df.groupby(['Away'])['Winner'].apply(lambda x: (x=='Draw').sum()
                                                           ).reset_index(name = 'Draw').rename(columns={'Away':'index'})
home_matches_draw = pl_df.groupby(['Home'])['Winner'].apply(lambda x: (x=='Draw').sum()
                                                           ).reset_index(name = 'Draw').rename(columns={'Home':'index'})
matches_drew = pd.concat([away_matches_draw, home_matches_draw])


############ Stacking up Match_Dataframe ############

match_df = season_played.merge(total_matches_played, how='right', on = 'index')
match_df2 = match_df.merge(matches_won, how='right', on = 'index')
match_df3 = match_df2.merge(matches_drew, how='right', on = 'index')
match_df3['Loss'] = match_df3['Matches Played'] - match_df3['Won'] - match_df3['Draw']

# %%
##### Goals scored by Teams 
total_goals_scored['GF'] = total_goals_scored['Home Goals'
                                                     ] + total_goals_scored['Away Goals']

##### Goals conceded by Teams
# First, Counting Goals conceded at Home by All Teams 
home_goal_conceded = pl_df.groupby(['Home'])['AwayGoals'].sum().reset_index()
home_goal_conceded.columns = ['index','Goals conceded at Home']

# Counting Goals conceded at Away by All Teams 
away_goal_conceded = pl_df.groupby(['Away'])['HomeGoals'].sum().reset_index()
away_goal_conceded.columns = ['index','Goals conceded at Away']

# Merging above dataframes to create a dataframe to know teams who conceded most in 
# both H & A goals in all fixtures since 1993 season

total_goal_conceded = pd.merge(home_goal_conceded, away_goal_conceded, how ='right',on ='index')
total_goal_conceded['GA'] = total_goal_conceded['Goals conceded at Home'
                                                           ] + total_goal_conceded['Goals conceded at Away']

##### Now merging both goal scored and conceded in a single dataframe

goal_history = pd.merge(total_goals_scored, total_goal_conceded, how ='right',on ='index')
all_time_goal_history = goal_history[['index','GF','GA']]
all_time_goal_history['GD'] = all_time_goal_history['GF'] - all_time_goal_history['GA']

# %%
# Now creating the All Time Ranking Table from 1993-2022 Season 

all_time_pl_table = match_df3.merge(all_time_goal_history, how ='right',on ='index').rename(columns={'index':'Team'})
all_time_pl_table.drop_duplicates(subset=['Team'], keep='first', inplace=True, ignore_index=True)

# In EPL, Three points are awarded for a win, one point for a draw and none for a defeat
all_time_pl_table['Points'] = (match_df3['Won'])*3 + (match_df3['Loss']*1)
# Addition columns to show win% of the teams 
all_time_pl_table['Win%'] = round((match_df3['Won']/match_df3['Matches Played'])*100,2)

# %%
all_time_pl_table.sort_values(by='Points', ascending = False, ignore_index=True)
# Out:
#                Team  Seasons  Matches Played  Won  Draw  Loss    GF    GA    GD  Points   Win%
# 0    Manchester Utd       30            1152  703   147   302  2185  1066  1119    2411  61.02
# 1           Chelsea       30            1152  618   141   393  1973  1125   848    2247  53.65
# 2           Arsenal       30            1152  619   153   380  2017  1148   869    2237  53.73
# 3         Liverpool       30            1152  609   145   398  2021  1147   874    2225  52.86
# 4         Tottenham       30            1152  502   149   501  1745  1438   307    2007  43.58
# 5           Everton       30            1152  418   166   568  1491  1481    10    1822  36.28
# 6   Manchester City       25             962  473   113   376  1658  1068   590    1795  49.17
# 7     Newcastle Utd       27            1034  382   136   516  1377  1417   -40    1662  36.94
# 8       Aston Villa       27            1038  354   145   539  1265  1353   -88    1601  34.10
# ...

# %% [markdown]
# The most successful manager in the Premier League is Alex Ferguson of Manchester United, who won 13 titles - more than three times as many as any other manager - between 1993 and 2013. Man Utd has winning output of 61.02% and highest points collected which is more than enough to give them a Legendary status.

# %% [markdown]
# # EPL 2002-2022 Premier League Standings Dataset

# %%
epl = pd.read_csv("eplStandings.csv")

# %%
epl.head()
# Out:
#     Season  Pos               Team  Pld   W   D   L  GF  GA  GD  Pts                        Qualification or relegation
# 0  2000-01    1  Manchester United   38  24   8   6  79  31  48   80  Qualification for the Champions League first g...
# 1  2000-01    2            Arsenal   38  20  10   8  63  38  25   70  Qualification for the Champions League first g...
# 2  2000-01    3          Liverpool   38  20   9   9  71  39  32   69  Qualification for the Champions League third q...
# 3  2000-01    4       Leeds United   38  20   8  10  64  43  21   68      Qualification for the UEFA Cup first round[a]
# 4  2000-01    5       Ipswich Town   38  20   6  12  57  42  15   66      Qualification for the UEFA Cup first round[a]

# %% [markdown]
# Meaning of each column :
#
# - Season -- Year in which the league was played
# - Pos -- Team position in the league
# - Team -- Team name
# - Pld -- Games played
# - W -- Games won
# - D -- Games tied
# - L -- Games lost
# - GF -- Goals for
# - GA -- Goals against
# - GD -- Goal difference
# - Pts -- Points won
# - Qualification or relegation -- Qualification to Europe Cups or relegation to Football League First Division

# %%
epl.isnull().values.any()
# Out:
# False

# %% [markdown]
# No Null Values

# %% [markdown]
# Let's see the Premier League winners

# %%
Winners = (epl[epl.Pos == 1])
Winners
# Out:
#       Season  Pos               Team  Pld   W   D  L   GF  GA  GD  Pts                        Qualification or relegation
# 0    2000-01    1  Manchester United   38  24   8  6   79  31  48   80  Qualification for the Champions League first g...
# 20   2001-02    1            Arsenal   38  26   9  3   79  36  43   87  Qualification for the Champions League first g...
# 40   2002-03    1  Manchester United   38  25   8  5   74  34  40   83  Qualification for the Champions League group s...
# 60   2003-04    1            Arsenal   38  26  12  0   73  26  47   90  Qualification for the Champions League group s...
# 80   2004-05    1            Chelsea   38  29   8  1   72  15  57   95  Qualification for the Champions League group s...
# 100  2005-06    1            Chelsea   38  29   4  5   72  22  50   91  Qualification for the Champions League group s...
# 120  2006-07    1  Manchester United   38  28   5  5   83  27  56   89  Qualification for the Champions League group s...
# ...

# %%
most_times_w = Winners.Team.value_counts()

# %%
sns.catplot(y = 'Team', kind='count', data = Winners, aspect = 2.5, order = most_times_w.index, palette = 'summer')
plt.title('Premier League Champions between 2000-2022', fontsize = 20)
plt.xlabel('Titles')
# Out:
# Text(0.5, 12.44444444444443, 'Titles')

# %%
best_campaings = Winners.sort_values('Pts',ascending=False)
best_campaings.head(1)
# Out:
#       Season  Pos             Team  Pld   W  D  L   GF  GA  GD  Pts                        Qualification or relegation
# 340  2017-18    1  Manchester City   38  32  4  2  106  27  79  100  Qualification for the Champions League group s...

# %% [markdown]
# We can see Manchester City is the best champion of the century winning the league in season 2017-18 with 100 points. Let's see now teams that ended in the last positions.

# %%
Losers = (epl[epl.Pos >= 18])
relegations = Losers.Team.value_counts()

# %%
plt.figure(figsize=(12, 12))
sns.barplot(x=relegations, y=relegations.index, palette = 'autumn')
plt.title('Premier League Relegations between 2000-2022');
plt.xlabel('Relegations');
plt.ylabel('Team');

# %% [markdown]
# West Bromwich Albion and Norwich City are the teams that have had the most relegations from 2000 to 2022.

# %%
worse_campaings = Losers.sort_values('Pts',ascending=False)
worse_campaings.tail(1)
# Out:
#       Season  Pos          Team  Pld  W  D   L  GF  GA  GD  Pts                     Qualification or relegation
# 159  2007-08   20  Derby County   38  1  8  29  20  89 -69   11  Relegation to the Football League Championship

# %% [markdown]
# Fun fact: Derby County's only win was against Newcastle at Home.

# %% [markdown]
# Team Finishing Positions Through the Years (2002-2022)

# %%
toon_df = epl[epl.Team == 'Newcastle United']
toon_df

toon_df.plot(x='Season', y='Pos', marker = 'o', ms = '6', lw = '3', mfc = 'red', c = 'black', alpha = 0.8, figsize=(15,10))

plt.xlabel('Season')
plt.ylabel('Position')

plt.title("Newcastle United positions between 2000-2022", fontsize = 20)
plt.legend(['Pos']);
plt.gca().invert_yaxis()

# %%
toon_goals_df = toon_df.groupby('Season').agg({'GF': 'sum'})

axun = toon_goals_df.plot(kind='bar',figsize=(15,10), color='black' , alpha = 0.8)
plt.xticks(rotation=65)
plt.title('Newcastle United total goals per season between 2000-2022',fontsize=20)
plt.ylabel('Goals',fontsize=20)
plt.xlabel('Season',fontsize=20);
axun.set_ylim(20, 110)
# Out:
# (20.0, 110.0)

# %%
wtoon_df = toon_df.groupby('Team').agg({'W': 'sum'})
ltoon_df = toon_df.groupby('Team').agg({'L': 'sum'})
dtoon_df = toon_df.groupby('Team').agg({'D': 'sum'})
tplayed_toon_df = toon_df.groupby('Team').agg({'Pld': 'sum'})

wltoon_df = pd.merge(wtoon_df, ltoon_df, on='Team')
wldtoon_df = pd.merge(wltoon_df, dtoon_df, on='Team')

stats_toon_df = pd.merge(wldtoon_df, tplayed_toon_df, on='Team')

pie_toon_df = stats_toon_df.copy()

pie_toon_df['W'] = pie_toon_df['W']/pie_toon_df['Pld']
pie_toon_df['L'] = pie_toon_df['L']/pie_toon_df['Pld']
pie_toon_df['D'] = pie_toon_df['D']/pie_toon_df['Pld']

del pie_toon_df['Pld']

#colors = ['red', 'yellowgreen', 'grey']
colors = ["#2ca02c", "#d62728", "grey"]


at = pie_toon_df.iloc[0].plot.pie(autopct='%1.1f%%', colors = colors, explode=[0.01, 0.01, 0.01], shadow=True,  startangle=0, legend=True, title='Air Termination System', ylabel='', labeldistance=None)
plt.title("Newcastle United\n" + "Percentage of wins, draws and losses between 2000 - 2022", bbox={'facecolor':'0.9', 'pad':10}, fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Newcastle United\nPercentage of wins, draws and losses between 2000 - 2022')

# %%
united_df = epl[epl.Team == 'Manchester United']
united_df

united_df.plot(x='Season', y='Pos', marker = 'o', ms = '6', lw = '3', mfc = 'black', c = 'red', alpha = 0.8, figsize=(15,10))

plt.xlabel('Season')
plt.ylabel('Position')

plt.title("Manchester United positions between 2000-2022", fontsize = 20)
plt.legend(['Pos']);
plt.gca().invert_yaxis()

# %%
united_goals_df = united_df.groupby('Season').agg({'GF': 'sum'})

axun = united_goals_df.plot(kind='bar',figsize=(15,10), color='red' , alpha = 0.8)
plt.xticks(rotation=65)
plt.title('Manchester United total goals per season between 2000-2022',fontsize=20)
plt.ylabel('Goals',fontsize=20)
plt.xlabel('Season',fontsize=20);
axun.set_ylim(20, 110)
# Out:
# (20.0, 110.0)

# %%
wunited_df = united_df.groupby('Team').agg({'W': 'sum'})
lunited_df = united_df.groupby('Team').agg({'L': 'sum'})
dunited_df = united_df.groupby('Team').agg({'D': 'sum'})
tplayed_united_df = united_df.groupby('Team').agg({'Pld': 'sum'})

wlunited_df = pd.merge(wunited_df, lunited_df, on='Team')
wldunited_df = pd.merge(wlunited_df, dunited_df, on='Team')

stats_united_df = pd.merge(wldunited_df, tplayed_united_df, on='Team')

pie_united_df = stats_united_df.copy()

pie_united_df['W'] = pie_united_df['W']/pie_united_df['Pld']
pie_united_df['L'] = pie_united_df['L']/pie_united_df['Pld']
pie_united_df['D'] = pie_united_df['D']/pie_united_df['Pld']

del pie_united_df['Pld']

#colors = ['red', 'yellowgreen', 'grey']
colors = ["#2ca02c", "#d62728", "grey"]


at = pie_united_df.iloc[0].plot.pie(autopct='%1.1f%%', colors = colors, explode=[0.01, 0.01, 0.01], shadow=True,  startangle=0, legend=True, title='Air Termination System', ylabel='', labeldistance=None)
plt.title("Manchester United\n" + "Percentage of wins, draws and losses between 2000 - 2022", bbox={'facecolor':'0.9', 'pad':10}, fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Manchester United\nPercentage of wins, draws and losses between 2000 - 2022')

# %% [markdown]
# # Comparing Derbys
#
# - Manchester United vs Manchester City
# - Newcastle United vs Sunderland AFC
# - Manchester United vs Liverpool
# - Liverpool vs Everton

# %%
city_df = epl[epl.Team == 'Manchester City']
sns.set(rc={'figure.figsize':(15,10)})

sns.lineplot(data=united_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['red'], alpha = 1)
sns.lineplot(data=city_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['xkcd:sky blue'], alpha = 1 )
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.xticks(rotation=65)
plt.title("Manchester United and Manchester City positions between 2000-2022",fontsize=20)
plt.gca().invert_yaxis()

# %%
sun_df = epl[epl.Team == 'Sunderland']
sns.set(rc={'figure.figsize':(15,10)})

sns.lineplot(data=toon_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['black'], alpha = 1)
sns.lineplot(data=sun_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['red'], alpha = 1 )
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.xticks(rotation=65)
plt.title("Newcastle United and Sunderland positions between 2000-2022",fontsize=20)
plt.gca().invert_yaxis()

# %%
liv_df = epl[epl.Team == 'Liverpool']
sns.lineplot(data=united_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['red'], alpha = 1)
sns.lineplot(data=liv_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['orange'], alpha = 1 )
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.xticks(rotation=65)
plt.title("Manchester United and Liverpool positions between 2000-2022",fontsize=20)
plt.gca().invert_yaxis()

# %%
everton_df = epl[epl.Team == 'Everton']

sns.lineplot(data=everton_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['blue'], alpha = 1)
sns.lineplot(data=liv_df, x='Season',y='Pos', hue='Team', marker = 'o', ms = '6', lw = '3', mfc = 'black', palette = ['orange'], alpha = 1 )
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.yticks(np.arange(min(city_df.Pos), max(city_df.Pos)+1, 1.0))
plt.xticks(rotation=65)
plt.title("Everton and Liverpool positions between 2000-2022",fontsize=20)
plt.gca().invert_yaxis()

# %%
total_goals_df = epl.groupby('Team').agg({'GF': 'sum'})

tg_df = total_goals_df.sort_values('GF', ascending = False)

tg_df.plot(kind='barh',figsize=(15,15), color='orange', alpha = 0.7)
plt.title('Total goals per team between 2000-2022',fontsize=25)
plt.ylabel('Team',fontsize=20)
plt.xlabel('Goals',fontsize=20);
plt.gca().invert_yaxis()

# %%
epl.head()
# Out:
#     Season  Pos               Team  Pld   W   D   L  GF  GA  GD  Pts                        Qualification or relegation
# 0  2000-01    1  Manchester United   38  24   8   6  79  31  48   80  Qualification for the Champions League first g...
# 1  2000-01    2            Arsenal   38  20  10   8  63  38  25   70  Qualification for the Champions League first g...
# 2  2000-01    3          Liverpool   38  20   9   9  71  39  32   69  Qualification for the Champions League third q...
# 3  2000-01    4       Leeds United   38  20   8  10  64  43  21   68      Qualification for the UEFA Cup first round[a]
# 4  2000-01    5       Ipswich Town   38  20   6  12  57  42  15   66      Qualification for the UEFA Cup first round[a]
